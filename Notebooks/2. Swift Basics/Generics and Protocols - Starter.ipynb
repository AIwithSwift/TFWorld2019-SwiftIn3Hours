// %% [markdown]
// # Starter - Generics and Protocols

// %% [markdown]
// ## Generics

// %% [markdown]
// This material is derivative of the Swift documentation.

// %%
// code goes here

// %%
// code goes here

// %%
// code goes here

// %%
// code goes here

// %%
// code goes here

// %%
// code goes here

// %%
// code goes here

// %% [markdown]
// ## Protocol-oriented Programming

// %%
// code goes here

// %%
// code goes here
